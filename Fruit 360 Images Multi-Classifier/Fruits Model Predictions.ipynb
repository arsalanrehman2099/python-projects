# %% [markdown]
# # Fruits Images Classifier

# %% [markdown]
# ## Predictions

# %%
import cv2
import joblib
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# %%
model = load_model('./model_fruits.h5')
fruit_names = joblib.load('./fruit_indexes')

# %%
def fruit_prediction(img_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    img = cv2.resize(img,(100,100))
    img = img.reshape(1,100, 100, 3)
    img = img/255
    res = np.argmax(model.predict(img), axis=-1)
    print('Fruit is: ',fruit_names[res[0]])

# %%
fruit_prediction('./DATA/test-multiple_fruits/Bananas(lady_finger)5.jpg')
# Out:
# Fruit is:  Banana Lady Finger

# %%
fruit_prediction('./DATA/test-multiple_fruits/orange.jpg')
# Out:
# Fruit is:  Pepper Orange
